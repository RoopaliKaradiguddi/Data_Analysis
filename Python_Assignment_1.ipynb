# %% [markdown]
# # PYTHON PROGRAMMING ASSIGNMENT

# %% [markdown]
# ### Exercise1: Check of Prime Number

# %%
Number=int(input("Enter a number:"))
prime=Number % 2
if(prime==1):
    print(Number," is a prime number")
else:
    print(Number," is not a prime number")
# Out:
# Enter a number: 16
# 16  is not a prime number

# %% [markdown]
# ### Excercise2: Product of Random Numbers

# %%
import numpy as np
b = np.random.randn(2)
print("Generated Numbers:",b)
computer= b[0]*b[1]
user=float(input("Enter Product of the Numbers"))
if user==computer:
    print("User entered answer is correct")
else:
    print("User entered answer is wrong")
    print("Correct product is:", computer)
# Out:
# Generated Numbers [-0.2083336   0.07434311]
# Enter Product of the Numbers -0.015488167741496
# User entered answer is wrong
# Correct product is: -0.015488166468185545

# %% [markdown]
# ### Excercise3: Square of Even/Odd Numbers

# %% [markdown]
# #### For Even Numbers

# %%
Range = range(100, 200, 2)
list(Range)
squares = [x**2 for x in Range]
print(squares)
# Out:
# [10000, 10404, 10816, 11236, 11664, 12100, 12544, 12996, 13456, 13924, 14400, 14884, 15376, 15876, 16384, 16900, 17424, 17956, 18496, 19044, 19600, 20164, 20736, 21316, 21904, 22500, 23104, 23716, 24336, 24964, 25600, 26244, 26896, 27556, 28224, 28900, 29584, 30276, 30976, 31684, 32400, 33124, 33856, 34596, 35344, 36100, 36864, 37636, 38416, 39204]

# %% [markdown]
# #### For Odd Numbers

# %%
Range = range(101, 200, 2)
list(Range)
squares = [x**2 for x in Range]
print(squares)
# Out:
# [10201, 10609, 11025, 11449, 11881, 12321, 12769, 13225, 13689, 14161, 14641, 15129, 15625, 16129, 16641, 17161, 17689, 18225, 18769, 19321, 19881, 20449, 21025, 21609, 22201, 22801, 23409, 24025, 24649, 25281, 25921, 26569, 27225, 27889, 28561, 29241, 29929, 30625, 31329, 32041, 32761, 33489, 34225, 34969, 35721, 36481, 37249, 38025, 38809, 39601]

# %% [markdown]
# ### Excercise4: Word Counter

# %%
input_text = ["This", "is", "a", "sample", "text", "This", "text", "will", "be", "used", "to", "demonstrate", "the", "word", "counter."]
len(input_text)
Count=input_text
Count
Word_Count= (Count.count("This"),
             Count.count("is"),
             Count.count("a"),
             Count.count("sample"),
             Count.count("text"))
print("This:",Word_Count[0])
print("is:",Word_Count[1])
print("a:",Word_Count[2])
print("sample:",Word_Count[3])
print("text:",Word_Count[4])
# Out:
# This: 2
# is: 1
# a: 1
# sample: 1
# text: 2

# %% [markdown]
# ### Excercise5: Check of Palindrome

# %%
String = str(input("Enter a String:"))
Reverse = (String[::-1])
if (String==Reverse):
    print(String,"is a Palindrome")
else:
    print(String,"is not a Palindrome")
# Out:
# Enter a String: abcba
# abcba is a Palindrome
